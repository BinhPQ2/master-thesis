# %% [markdown]
# # Raw data directory

# %%
data_dir = "../data/raw/"
data_dir = data_dir.rstrip("/")
print(f"data_dir: {data_dir}")  # Output: ../data/raw
# Out:
# data_dir: ../data/raw

# %% [markdown]
# # Elinimate manga that is not existed in both EN and VI

# %%
import os

languages = ["en", "vi"]

manga_sets = {}
for lang in languages:
    lang_dir = os.path.join(data_dir, lang)
    if os.path.exists(lang_dir):
        manga_sets[lang] = set(
            name for name in os.listdir(lang_dir)
            if os.path.isdir(os.path.join(lang_dir, name))
        )
    else:
        manga_sets[lang] = set()

# Find manga not present in both languages
only_in_en = manga_sets["en"] - manga_sets["vi"]
only_in_vi = manga_sets["vi"] - manga_sets["en"]
missing_titles = {
    "en": only_in_en,
    "vi": only_in_vi
}

print("Manga only in EN:", missing_titles["en"])
print("Manga only in VI:", missing_titles["vi"])
# Out:
# Manga only in EN: set()
# Manga only in VI: {'test_data', 'Ghost Fixers', 'Night Light Hounds', 'The Marshal King', 'Empyreal Cabinet', 'Ultimate Exorcist Kiyoshi'}

# %%
import os
import shutil
from datetime import datetime

missing_title_dir = os.path.join(os.path.dirname(data_dir), "missing_titles")
print(missing_title_dir)
languages = ["en", "vi"]
missing_title_dir_log_path = os.path.join(missing_title_dir, "history_log.txt")

for lang in languages:
    os.makedirs(os.path.join(missing_title_dir, lang), exist_ok=True)
    for manga in missing_titles[lang]:
        src = os.path.join(data_dir, lang, manga)
        dst = os.path.join(missing_title_dir, lang, manga)
        if os.path.exists(src):
            shutil.move(src, dst)
            log_entry = f"{datetime.now().isoformat()} - {manga} → {lang}\n"
            print(log_entry)
            with open(missing_title_dir_log_path, "a") as log_file:
                log_file.write(log_entry)
# Out:
# ../data\missing_titles
# 2025-11-05T17:36:20.224021 - test_data → vi
#
# 2025-11-05T17:36:20.225134 - Ghost Fixers → vi
#
# 2025-11-05T17:36:20.225610 - Night Light Hounds → vi
#
# 2025-11-05T17:36:20.226058 - The Marshal King → vi
#
# 2025-11-05T17:36:20.226560 - Empyreal Cabinet → vi
#
# 2025-11-05T17:36:20.227162 - Ultimate Exorcist Kiyoshi → vi

# %% [markdown]
# # Eliminate manga with un-equal number of chapters.

# %%
import os
import shutil
from datetime import datetime 

missing_chapter_dir = os.path.join(os.path.dirname(data_dir), "missing_chapters")
languages = ["en", "vi"]
manga_common = set(os.listdir(os.path.join(data_dir, "en"))) & set(os.listdir(os.path.join(data_dir, "vi")))
missing_chapter_dir_log_path = os.path.join(missing_chapter_dir, "history_log.txt")

for lang in languages:
    os.makedirs(os.path.join(missing_chapter_dir, lang), exist_ok=True)

for manga in manga_common:
    character_dict = {}
    for lang in languages:
        character_dict[lang] = os.listdir(os.path.join(data_dir, lang, manga))

    if character_dict["en"] != character_dict["vi"]:
        for lang in languages:
            src = os.path.join(data_dir, lang, manga)
            dst = os.path.join(missing_chapter_dir, lang, manga)
            shutil.move(src, dst)
            log_entry = f"{datetime.now().isoformat()} - {manga} → {lang}\n"
            print(log_entry)
            with open(missing_chapter_dir_log_path, "a") as log_file:
                log_file.write(log_entry)
# Out:
# 2025-11-05T17:45:15.596389 - Kurokami Seiso no Reikoku Bishoujo o Tasuketara, Ore to Futarikiri no Toki dake Dereru You ni Natta Ken → en
#
# 2025-11-05T17:45:15.597398 - Kurokami Seiso no Reikoku Bishoujo o Tasuketara, Ore to Futarikiri no Toki dake Dereru You ni Natta Ken → vi
#
# 2025-11-05T17:45:15.598463 - Kimi wa Ore no Yasashikunai Haru → en
#
# 2025-11-05T17:45:15.599007 - Kimi wa Ore no Yasashikunai Haru → vi
#
# 2025-11-05T17:45:15.609617 - Kaji Daikou no Arubaito wo Hajimetara Gakuen Ichi no Bishoujo no Kazoku ni Kiniirarechaimashita → en
#
# 2025-11-05T17:45:15.610433 - Kaji Daikou no Arubaito wo Hajimetara Gakuen Ichi no Bishoujo no Kazoku ni Kiniirarechaimashita → vi
#
# 2025-11-05T17:45:15.614050 - Eclair - Anata ni Hibiku Yuri Anthology → en
#
# 2025-11-05T17:45:15.614735 - Eclair - Anata ni Hibiku Yuri Anthology → vi
#
# 2025-11-05T17:45:15.615598 - Tonari no Wakao-san wa Miesou de Mienai → en
#
# 2025-11-05T17:45:15.616067 - Tonari no Wakao-san wa Miesou de Mienai → vi
#
# 2025-11-05T17:45:15.618329 - Bakajo 26-ji → en
#
# 2025-11-05T17:45:15.618869 - Bakajo 26-ji → vi
#
# 2025-11-05T17:45:15.620085 - Ookami wa Tsuki ni Koi wo Suru → en
#
# 2025-11-05T17:45:15.620599 - Ookami wa Tsuki ni Koi wo Suru → vi
#
# 2025-11-05T17:45:15.621513 - Ashita, Hadashi de Koi → en
#
# 2025-11-05T17:45:15.622362 - Ashita, Hadashi de Koi → vi
#
# 2025-11-05T17:45:15.634217 - NEW GAME! → en
#
# 2025-11-05T17:45:15.635283 - NEW GAME! → vi
#
# 2025-11-05T17:45:15.643621 - Wakaba-san'chi no Aoi Koi → en
#
# 2025-11-05T17:45:15.644259 - Wakaba-san'chi no Aoi Koi → vi
#
# 2025-11-05T17:45:15.646252 - Class de 2-banme ni Kawaii Onnanoko to Tomodachi ni Natta → en
#
# 2025-11-05T17:45:15.647303 - Class de 2-banme ni Kawaii Onnanoko to Tomodachi ni Natta → vi
#
# 2025-11-05T17:45:15.652838 - The Raise → en
#
# 2025-11-05T17:45:15.653667 - The Raise → vi
#
# 2025-11-05T17:45:15.660061 - Tonikaku Kawaii → en
#
# 2025-11-05T17:45:15.661236 - Tonikaku Kawaii → vi
#
# 2025-11-05T17:45:15.674525 - Onii-chan Is Done For! → en
#
# 2025-11-05T17:45:15.675706 - Onii-chan Is Done For! → vi
#
# 2025-11-05T17:45:15.681315 - Mudameshi Kurai Nintei Sareta node Aiso o Tsukashi, Teikoku ni Utsute Shusse Suru → en
#
# 2025-11-05T17:45:15.682209 - Mudameshi Kurai Nintei Sareta node Aiso o Tsukashi, Teikoku ni Utsute Shusse Suru → vi
#
# 2025-11-05T17:45:15.689511 - Majo Taisen - 32-nin no Isai no Majo wa Koroshiau → en
#
# 2025-11-05T17:45:15.690481 - Majo Taisen - 32-nin no Isai no Majo wa Koroshiau → vi

# %% [markdown]
# # Eliminate manga with un-equal number of page per chapter

# %%
import os
import shutil
from datetime import datetime

unequal_page_dir = os.path.join(os.path.dirname(data_dir), "missing_pages")
languages = ["en", "vi"]
manga_common = set(os.listdir(os.path.join(data_dir, "en"))) & set(os.listdir(os.path.join(data_dir, "vi")))
unequal_page_dir_log_path = os.path.join(unequal_page_dir, "history_log.txt")

for lang in languages:
    os.makedirs(os.path.join(unequal_page_dir, lang), exist_ok=True)

def list_dirs(path):
    return [name for name in os.listdir(path) if os.path.isdir(os.path.join(path, name))]


for manga in manga_common:
    # Get chapter lists for both languages
    en_chapters = list_dirs(os.path.join(data_dir, "en", manga))
    vi_chapters = list_dirs(os.path.join(data_dir, "vi", manga))
    # Only check chapters that exist in both
    common_chapters = set(en_chapters) & set(vi_chapters)
    unequal = False
    for chapter in common_chapters:
        en_pages = os.listdir(os.path.join(data_dir, "en", manga, chapter))
        vi_pages = os.listdir(os.path.join(data_dir, "vi", manga, chapter))
        if len(en_pages) != len(vi_pages):
            unequal = True
            break
    if unequal:
        for lang in languages:
            src = os.path.join(data_dir, lang, manga)
            dst = os.path.join(unequal_page_dir, lang, manga)
            if os.path.exists(src):
                shutil.move(src, dst)
                log_entry = f"{datetime.now().isoformat()} - {manga} → {lang}\n"
                print(log_entry)
                with open(unequal_page_dir_log_path, "a") as log_file:
                    log_file.write(log_entry)
# Out:
# 2025-11-05T18:20:49.435912 - Koi yori Aoku → en
#
# 2025-11-05T18:20:49.436905 - Koi yori Aoku → vi
#
# 2025-11-05T18:20:49.438058 - Soshiki no Shukuteki to Kekkon Shitara Mecha Amai → en
#
# 2025-11-05T18:20:49.438941 - Soshiki no Shukuteki to Kekkon Shitara Mecha Amai → vi
#
# 2025-11-05T18:20:49.440309 - Imokusa Reijou desu ga Akuyaku Reisoku wo Tasuketara Kiniiraremashita → en
#
# 2025-11-05T18:20:49.441014 - Imokusa Reijou desu ga Akuyaku Reisoku wo Tasuketara Kiniiraremashita → vi
#
# 2025-11-05T18:20:49.441817 - FateSamurai Remnant → en
#
# 2025-11-05T18:20:49.442288 - FateSamurai Remnant → vi
#
# 2025-11-05T18:20:49.443110 - Nibanme na Boku to Ichiban no Kanojo → en
#
# 2025-11-05T18:20:49.443534 - Nibanme na Boku to Ichiban no Kanojo → vi
#
# 2025-11-05T18:20:49.444434 - Okinawa de Suki ni Natta Ko ga Hougen Sugite Tsura Sugiru → en
#
# 2025-11-05T18:20:49.444869 - Okinawa de Suki ni Natta Ko ga Hougen Sugite Tsura Sugiru → vi
#
# 2025-11-05T18:20:49.448618 - Shy → en
#
# 2025-11-05T18:20:49.449185 - Shy → vi
#
# 2025-11-05T18:20:49.450058 - Alma → en
#
# 2025-11-05T18:20:49.450603 - Alma → vi
#
# 2025-11-05T18:20:49.451602 - Asahina-san no Bentou Tabetai → en
#
# 2025-11-05T18:20:49.452011 - Asahina-san no Bentou Tabetai → vi
#
# 2025-11-05T18:20:49.452717 - Haru no Regista → en
#
# 2025-11-05T18:20:49.453109 - Haru no Regista → vi
#
# 2025-11-05T18:20:49.453840 - Boku dake ga Shitterun daze → en
#
# 2025-11-05T18:20:49.454267 - Boku dake ga Shitterun daze → vi
#
# 2025-11-05T18:20:49.456097 - Botsuraku Yotei Nanode, Kajishokunin wo Mezasu → en
#
# 2025-11-05T18:20:49.456614 - Botsuraku Yotei Nanode, Kajishokunin wo Mezasu → vi
#
# 2025-11-05T18:20:49.466098 - Nine Peaks → en
#
# 2025-11-05T18:20:49.466631 - Nine Peaks → vi
#
# 2025-11-05T18:20:49.467544 - Kusuriya no Hitorigoto Maomao no Koukyuu Nazotoki Techou → en
#
# 2025-11-05T18:20:49.467931 - Kusuriya no Hitorigoto Maomao no Koukyuu Nazotoki Techou → vi
#
# 2025-11-05T18:20:49.469284 - Osananajimi Kanojo no Morahara ga Hidoin de Zetsuen Sengen shite Yatta ~Jibun Rashiku Ikiru Koto ni Shitara, Naze ka Tonari no Seki no Kakure Bishoujo kara Kokuhaku Sareta~ → en
#
# 2025-11-05T18:20:49.469802 - Osananajimi Kanojo no Morahara ga Hidoin de Zetsuen Sengen shite Yatta ~Jibun Rashiku Ikiru Koto ni Shitara, Naze ka Tonari no Seki no Kakure Bishoujo kara Kokuhaku Sareta~ → vi
#
# 2025-11-05T18:20:49.541265 - Kidou Senshi Gundam Suisei no Majo - Seishun Frontier → en
#
# 2025-11-05T18:20:49.542690 - Kidou Senshi Gundam Suisei no Majo - Seishun Frontier → vi
#
# 2025-11-05T18:20:49.543689 - Ochinai Yogore wo Boku wa Nanto Yobeba Yokatta noka → en
#
# 2025-11-05T18:20:49.544210 - Ochinai Yogore wo Boku wa Nanto Yobeba Yokatta noka → vi
#
# 2025-11-05T18:20:49.544968 - Housekishou no Maid → en
#
# 2025-11-05T18:20:49.545711 - Housekishou no Maid → vi
#
# 2025-11-05T18:20:49.546695 - Slime Seijo → en
#
# 2025-11-05T18:20:49.547157 - Slime Seijo → vi
#
# 2025-11-05T18:20:49.548657 - Touhou Suichouka ~ Lotus Eater-tachi no Suisei → en
#
# 2025-11-05T18:20:49.549167 - Touhou Suichouka ~ Lotus Eater-tachi no Suisei → vi
#
# 2025-11-05T18:20:49.549937 - Make Heroine wo Katasetai!! → en
#
# 2025-11-05T18:20:49.550358 - Make Heroine wo Katasetai!! → vi
#
# 2025-11-05T18:20:49.551404 - Osoraku Kanojo wa Ore no Aniki wo Neratteru → en
#
# 2025-11-05T18:20:49.551802 - Osoraku Kanojo wa Ore no Aniki wo Neratteru → vi
#
# 2025-11-05T18:20:49.552479 - Suufungo no Mirai ga Wakaru You ni Natta kedo, Onnagokoro wa Wakaranai → en
#
# 2025-11-05T18:20:49.552873 - Suufungo no Mirai ga Wakaru You ni Natta kedo, Onnagokoro wa Wakaranai → vi
#
# 2025-11-05T18:20:49.555523 - Uma Musume Cinderella Gray → en
#
# 2025-11-05T18:20:49.556177 - Uma Musume Cinderella Gray → vi
#
# 2025-11-05T18:20:49.557238 - Rojiura de Hirotta Onnanoko ga Bad End-go no Otome Game no Heroine Datta Ken → en
#
# 2025-11-05T18:20:49.557812 - Rojiura de Hirotta Onnanoko ga Bad End-go no Otome Game no Heroine Datta Ken → vi
#
# 2025-11-05T18:20:49.558440 - Doku Doku Mori Mori → en
#
# 2025-11-05T18:20:49.558816 - Doku Doku Mori Mori → vi
#
# 2025-11-05T18:20:49.559631 - Shura no Hakoniwa → en
#
# 2025-11-05T18:20:49.560546 - Shura no Hakoniwa → vi
#
# 2025-11-05T18:20:49.565326 - HUNTER x HUNTER (Official Colored) → en
#
# 2025-11-05T18:20:49.566354 - HUNTER x HUNTER (Official Colored) → vi
#
# 2025-11-05T18:20:49.571725 - Otonari no Tenshi-sama ni Itsunomanika Dame Ningen ni Sareteita Ken → en
#
# 2025-11-05T18:20:49.572387 - Otonari no Tenshi-sama ni Itsunomanika Dame Ningen ni Sareteita Ken → vi
#
# 2025-11-05T18:20:49.573452 - Takou no Koori Hime o Tasuketara, Otomodachi kara Hajimeru Koto ni Narimashita → en
#
# 2025-11-05T18:20:49.573915 - Takou no Koori Hime o Tasuketara, Otomodachi kara Hajimeru Koto ni Narimashita → vi
#
# 2025-11-05T18:20:49.574627 - Houkago, Family Restaurant de, Class no Ano Ko to → en
#
# 2025-11-05T18:20:49.575052 - Houkago, Family Restaurant de, Class no Ano Ko to → vi
#
# 2025-11-05T18:20:49.577501 - Yuru Camp△ → en
#
# 2025-11-05T18:20:49.578077 - Yuru Camp△ → vi
#
# 2025-11-05T18:20:49.579851 - Bocchi the Rock! Gaiden - Hiroi Kikuri no Fukazake Nikki → en
#
# 2025-11-05T18:20:49.580420 - Bocchi the Rock! Gaiden - Hiroi Kikuri no Fukazake Nikki → vi
#
# 2025-11-05T18:20:49.581177 - Outo no Hazure no Renkinjutsushi ~Hazure Shokugyou Datta node, Nonbiri Omise Keiei Shimasu~ → en
#
# 2025-11-05T18:20:49.581622 - Outo no Hazure no Renkinjutsushi ~Hazure Shokugyou Datta node, Nonbiri Omise Keiei Shimasu~ → vi
#
# 2025-11-05T18:20:49.583049 - Otonari no Tenshi-sama ni Itsunomanika Dame Ningen ni Sareteita Ken after the rain → en
#
# 2025-11-05T18:20:49.583507 - Otonari no Tenshi-sama ni Itsunomanika Dame Ningen ni Sareteita Ken after the rain → vi
#
# 2025-11-05T18:20:49.587458 - Tenshi to Akuto!! → en
#
# 2025-11-05T18:20:49.587964 - Tenshi to Akuto!! → vi
#
# 2025-11-05T18:20:49.625590 - Yu-Gi-Oh! OCG Structures → en
#
# 2025-11-05T18:20:49.626990 - Yu-Gi-Oh! OCG Structures → vi
#
# 2025-11-05T18:20:49.628049 - Bokura ni wa Bokura no Kotoba ga aru → en
#
# 2025-11-05T18:20:49.628528 - Bokura ni wa Bokura no Kotoba ga aru → vi
#
# 2025-11-05T18:20:49.629146 - Shoujo Seikan Hyouryuuki → en
#
# 2025-11-05T18:20:49.629530 - Shoujo Seikan Hyouryuuki → vi
#
# 2025-11-05T18:20:49.630354 - Kaii-san and I → en
#
# 2025-11-05T18:20:49.630746 - Kaii-san and I → vi
#
# 2025-11-05T18:20:49.631555 - Centuria → en
#
# 2025-11-05T18:20:49.632067 - Centuria → vi
#
# 2025-11-05T18:20:49.632849 - Inu ga Hito ni Naru Hanashi → en
#
# 2025-11-05T18:20:49.633320 - Inu ga Hito ni Naru Hanashi → vi
#
# 2025-11-05T18:20:49.634002 - Rekkyou Sensen → en
#
# 2025-11-05T18:20:49.634448 - Rekkyou Sensen → vi
#
# 2025-11-05T18:20:49.635542 - Houkago, Bokura wa Uchuu ni Madou → en
#
# 2025-11-05T18:20:49.636048 - Houkago, Bokura wa Uchuu ni Madou → vi
#
# 2025-11-05T18:20:49.636782 - Mahou Shoujo no Majo Saiban → en
#
# 2025-11-05T18:20:49.637213 - Mahou Shoujo no Majo Saiban → vi
#
# 2025-11-05T18:20:49.637922 - Baka Ni Kokuhaku → en
#
# 2025-11-05T18:20:49.638315 - Baka Ni Kokuhaku → vi
#
# 2025-11-05T18:20:49.640440 - Kakkoii Onnanoko to 12-centi no Yakusoku → en
#
# 2025-11-05T18:20:49.641204 - Kakkoii Onnanoko to 12-centi no Yakusoku → vi
#
# 2025-11-05T18:20:49.643568 - Kao ni Denai Kashiwada-san to Kao ni Deru Oota-kun → en
#
# 2025-11-05T18:20:49.644066 - Kao ni Denai Kashiwada-san to Kao ni Deru Oota-kun → vi
#
# 2025-11-05T18:20:49.644762 - Ruri Dragon (Oneshot) → en
#
# 2025-11-05T18:20:49.645491 - Ruri Dragon (Oneshot) → vi
#
# 2025-11-05T18:20:49.653377 - Mairimashita! Iruma-kun → en
#
# 2025-11-05T18:20:49.653976 - Mairimashita! Iruma-kun → vi
#
# 2025-11-05T18:20:49.654909 - Tsuki wa Hitsuji wo Kazoenai → en
#
# 2025-11-05T18:20:49.655393 - Tsuki wa Hitsuji wo Kazoenai → vi
#
# 2025-11-05T18:20:49.656202 - Haikei, Arishi Hi ni Saku Hanatachi e → en
#
# 2025-11-05T18:20:49.656637 - Haikei, Arishi Hi ni Saku Hanatachi e → vi
#
# 2025-11-05T18:20:49.658138 - Homura-sensei Is Probably Unpopular → en
#
# 2025-11-05T18:20:49.658720 - Homura-sensei Is Probably Unpopular → vi
