# %% [markdown]
# # Raw data directory

# %%
# Import config
from pathlib import Path
import sys

p = Path.cwd()
for _ in range(6):
    if (p / "dir_config.py").exists():
        sys.path.insert(0, str(p))
        break
    p = p.parent

from dir_config import *

# create main dirs + language subfolders
ensure_dirs(DATA_DIR, RAW_DIR, RESULT_DIR, MODELS_DIR, CHARACTER_DIR, TEST_DATA_DIR)
ensure_dirs(*(RAW_DIR / lang for lang in LANGUAGES))
ensure_dirs(*(RESULT_DIR / lang for lang in LANGUAGES))

# %%
data_dir = RAW_DIR
print(f"data_dir: {data_dir}")  # Output: ../data/raw
# Out:
# data_dir: D:\Downloads\Tu_Lieu\Cao_Hoc\Master_Thesis\master-thesis\data\raw

# %% [markdown]
# # Move manga that is not existed in both EN and VI

# %%
import os

languages = ["en", "vi"]

manga_sets = {}
for lang in languages:
    lang_dir = os.path.join(data_dir, lang)
    if os.path.exists(lang_dir):
        manga_sets[lang] = set(
            name
            for name in os.listdir(lang_dir)
            if os.path.isdir(os.path.join(lang_dir, name))
        )
    else:
        manga_sets[lang] = set()

# Find manga not present in both languages
only_in_en = manga_sets["en"] - manga_sets["vi"]
only_in_vi = manga_sets["vi"] - manga_sets["en"]
missing_titles = {"en": only_in_en, "vi": only_in_vi}

print("Manga only in EN:", missing_titles["en"])
print("Manga only in VI:", missing_titles["vi"])
# Out:
# Manga only in EN: set()
# Manga only in VI: {'test_data', 'Ghost Fixers', 'Night Light Hounds', 'The Marshal King', 'Empyreal Cabinet', 'Ultimate Exorcist Kiyoshi'}

# %%
import os
import shutil
from datetime import datetime

missing_title_dir = os.path.join(os.path.dirname(data_dir), "missing_titles")
print(missing_title_dir)
languages = ["en", "vi"]
missing_title_dir_log_path = os.path.join(missing_title_dir, "history_log.txt")

for lang in languages:
    os.makedirs(os.path.join(missing_title_dir, lang), exist_ok=True)
    for manga in missing_titles[lang]:
        src = os.path.join(data_dir, lang, manga)
        dst = os.path.join(missing_title_dir, lang, manga)
        if os.path.exists(src):
            shutil.move(src, dst)
            log_entry = f"{datetime.now().isoformat()} - {manga} → {lang}\n"
            print(log_entry)
            with open(missing_title_dir_log_path, "a") as log_file:
                log_file.write(log_entry)
# Out:
# ../data\missing_titles
# 2025-11-05T17:36:20.224021 - test_data → vi
#
# 2025-11-05T17:36:20.225134 - Ghost Fixers → vi
#
# 2025-11-05T17:36:20.225610 - Night Light Hounds → vi
#
# 2025-11-05T17:36:20.226058 - The Marshal King → vi
#
# 2025-11-05T17:36:20.226560 - Empyreal Cabinet → vi
#
# 2025-11-05T17:36:20.227162 - Ultimate Exorcist Kiyoshi → vi

# %% [markdown]
# # Move manga's missing chapters of manga with un-equal number of chapters.

# %%
from datetime import datetime
import os
import shutil

missing_chapter_dir = os.path.join(
    os.path.dirname(data_dir), "missing_chapters"
)
languages = ["en", "vi"]
manga_common = set(os.listdir(os.path.join(data_dir, "en"))) & set(
    os.listdir(os.path.join(data_dir, "vi"))
)
missing_chapter_dir_log_path = os.path.join(
    missing_chapter_dir, "history_log.txt"
)

for lang in languages:
    os.makedirs(os.path.join(missing_chapter_dir, lang), exist_ok=True)

for manga in manga_common:
    en_chapters = set(os.listdir(os.path.join(data_dir, "en", manga)))
    vi_chapters = set(os.listdir(os.path.join(data_dir, "vi", manga)))

    # Find chapters present in one language but missing in the other
    missing_in_vi = en_chapters - vi_chapters  # Chapters only in EN
    missing_in_en = vi_chapters - en_chapters  # Chapters only in VI

    # Move chapters present in EN but missing in VI
    for chapter in missing_in_vi:
        src = os.path.join(data_dir, "en", manga, chapter)
        dst_dir = os.path.join(missing_chapter_dir, "en", manga)
        os.makedirs(dst_dir, exist_ok=True)
        shutil.move(src, os.path.join(dst_dir, chapter))

        log_entry = (
            f"{datetime.now().isoformat()} - {manga}/{chapter} → en (unpaired)\n"
        )
        print(log_entry, end="")
        with open(
            missing_chapter_dir_log_path, "a", encoding="utf-8"
        ) as log_file:
            log_file.write(log_entry)

    # Move chapters present in VI but missing in EN
    for chapter in missing_in_en:
        src = os.path.join(data_dir, "vi", manga, chapter)
        dst_dir = os.path.join(missing_chapter_dir, "vi", manga)
        os.makedirs(dst_dir, exist_ok=True)
        shutil.move(src, os.path.join(dst_dir, chapter))

        log_entry = (
            f"{datetime.now().isoformat()} - {manga}/{chapter} → vi (unpaired)\n"
        )
        print(log_entry, end="")
        with open(
            missing_chapter_dir_log_path, "a", encoding="utf-8"
        ) as log_file:
            log_file.write(log_entry)
# Out:
# 2026-09-06T02:39:43.117776 - Ookami wa Tsuki ni Koi wo Suru/Ch. 24 → en (unpaired)
# 2026-09-06T02:39:43.122429 - Eclair - Anata ni Hibiku Yuri Anthology/Vol. 2 Ch. 2 → vi (unpaired)
# 2026-09-06T02:39:43.123790 - Eclair - Anata ni Hibiku Yuri Anthology/Vol. 3 Ch. 11 → vi (unpaired)
# 2026-09-06T02:39:43.125535 - Eclair - Anata ni Hibiku Yuri Anthology/Vol. 4 Ch. 5 → vi (unpaired)
# 2026-09-06T02:39:43.127235 - Eclair - Anata ni Hibiku Yuri Anthology/Vol. 5 Ch. 13 → vi (unpaired)
# 2026-09-06T02:39:43.128877 - Eclair - Anata ni Hibiku Yuri Anthology/Vol. 4 Ch. 15 → vi (unpaired)
# 2026-09-06T02:39:43.130742 - Eclair - Anata ni Hibiku Yuri Anthology/Vol. 4 Ch. 4 → vi (unpaired)
# 2026-09-06T02:39:43.132184 - Eclair - Anata ni Hibiku Yuri Anthology/Vol. 2 Ch. 4 → vi (unpaired)
# 2026-09-06T02:39:43.133508 - Eclair - Anata ni Hibiku Yuri Anthology/Vol. 4 Ch. 14 → vi (unpaired)
# 2026-09-06T02:39:43.134815 - Eclair - Anata ni Hibiku Yuri Anthology/Vol. 3 Ch. 5 → vi (unpaired)
# ...

# %% [markdown]
# Attempt to fix the missing chapter manga because many of them simply having a different name

# %%
from datetime import datetime
import os
import re

attempt_fix_log_path = os.path.join(missing_chapter_dir, "fix_attempt.txt")


def extract_chapter_clean_name(folder_name):
    """Extracts 'Ch. X' or 'Ch. X.Y' from a string, ignoring any leading volume info."""
    match = re.search(r"^(.*?)(Ch\.\s*[\d\.]+)", folder_name, re.IGNORECASE)
    if not match:
        return None, False

    prefix = match.group(1).strip()
    raw_ch = match.group(2)

    # Cleanly remove "Ch." / "ch." from the front while keeping the full number intact (e.g., '32.2')
    num_part = re.sub(r"^Ch\.\s*", "", raw_ch, flags=re.IGNORECASE).strip()
    clean_name = f"Ch. {num_part}"

    has_prefix = len(prefix) > 0
    return clean_name, has_prefix


def rename_matching_chapters():
    en_missing = os.path.join(missing_chapter_dir, "en")
    vi_missing = os.path.join(missing_chapter_dir, "vi")

    if not os.path.exists(en_missing) or not os.path.exists(vi_missing):
        print("⚠️ Missing chapters folder structure not found.")
        return

    # Log setup (fixed mkdir for string path)
    os.makedirs(missing_chapter_dir, exist_ok=True)
    with open(attempt_fix_log_path, "a", encoding="utf-8") as log_f:
        log_f.write("=== RENAME MATCHING CHAPTERS ATTEMPT LOG ===\n")

    # Fixed directory scanning for string paths
    mangas_in_en = (
        {d for d in os.listdir(en_missing) if os.path.isdir(os.path.join(en_missing, d))}
        if os.path.exists(en_missing)
        else set()
    )
    mangas_in_vi = (
        {d for d in os.listdir(vi_missing) if os.path.isdir(os.path.join(vi_missing, d))}
        if os.path.exists(vi_missing)
        else set()
    )
    common_mangas = mangas_in_en & mangas_in_vi

    renamed_count = 0

    for manga in common_mangas:
        en_manga_dir = os.path.join(en_missing, manga)
        vi_manga_dir = os.path.join(vi_missing, manga)

        en_chapters = [
            c for c in os.listdir(en_manga_dir)
            if os.path.isdir(os.path.join(en_manga_dir, c))
        ]
        vi_chapters = [
            c for c in os.listdir(vi_manga_dir)
            if os.path.isdir(os.path.join(vi_manga_dir, c))
        ]

        # Maps cleaned chapter name -> folder name
        en_map = {}
        for c in en_chapters:
            clean_name, _ = extract_chapter_clean_name(c)
            if clean_name:
                en_map[clean_name] = c

        vi_map = {}
        for c in vi_chapters:
            clean_name, _ = extract_chapter_clean_name(c)
            if clean_name:
                vi_map[clean_name] = c

        # Only process chapters that exist in BOTH en and vi after trimming
        common_clean_chapters = set(en_map.keys()) & set(vi_map.keys())

        for clean_ch_name in common_clean_chapters:
            en_folder_name = en_map[clean_ch_name]
            vi_folder_name = vi_map[clean_ch_name]

            # Check if either folder needs prefix removal
            _, en_has_prefix = extract_chapter_clean_name(en_folder_name)
            _, vi_has_prefix = extract_chapter_clean_name(vi_folder_name)

            # Skip if both are already in clean 'Ch. X' format
            if not en_has_prefix and not vi_has_prefix:
                continue

            old_en_path = os.path.join(en_manga_dir, en_folder_name)
            old_vi_path = os.path.join(vi_manga_dir, vi_folder_name)

            new_en_path = os.path.join(en_manga_dir, clean_ch_name)
            new_vi_path = os.path.join(vi_manga_dir, clean_ch_name)

            # In-place rename for EN
            if old_en_path != new_en_path:
                os.rename(old_en_path, new_en_path)

            # In-place rename for VI
            if old_vi_path != new_vi_path:
                os.rename(old_vi_path, new_vi_path)

            log_entry = (
                f"{datetime.now().isoformat()} - RENAMED MATCH: [{manga}]\n"
                f"  EN: '{en_folder_name}' → '{clean_ch_name}'\n"
                f"  VI: '{vi_folder_name}' → '{clean_ch_name}'\n\n"
            )

            print(log_entry, end="")
            with open(attempt_fix_log_path, "a", encoding="utf-8") as log_f:
                log_f.write(log_entry)

            renamed_count += 1

    print(f"\n🎉 Done! Renamed {renamed_count} matching chapter pairs.")


if __name__ == "__main__":
    rename_matching_chapters()
# Out:
# 2026-09-06T02:37:54.407321 - RENAMED MATCH: [Class de 2-banme ni Kawaii Onnanoko to Tomodachi ni Natta]
#   EN: 'Vol. 6 Ch. 32.1' → 'Ch. 32.1'
#   VI: 'Ch. 32.1' → 'Ch. 32.1'
#
#
# 🎉 Done! Renamed 1 matching chapter pairs.

# %% [markdown]
# # Filter out only matched images

# %%
import os
from pathlib import Path
import shutil

import cv2
import numpy as np
from tqdm import tqdm

try:
    import imagehash
except Exception:
    imagehash = None

try:
    from skimage.metrics import structural_similarity as ssim
except Exception:
    ssim = None

# -------------------------------
# MATCHED CRITERIA CONFIG
# -------------------------------
SSIM_THRESHOLD = 0.75
HIST_CORRELATION_THRESHOLD = 0.90

HIST_CORRELATION_FALLBACK = 0.98
ORB_MATCH_RATIO_FALLBACK = 0.15


# -------------------------------
# COMPARED METRICS
# -------------------------------
def _read_image_cv(path, flags=cv2.IMREAD_COLOR):
    img = cv2.imread(path, flags)
    if img is None:
        raise FileNotFoundError(f"Cannot read image: {path}")
    return img


def _to_gray(img):
    return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)


def _resize_to_min(img1, img2):
    h1, w1 = img1.shape[:2]
    h2, w2 = img2.shape[:2]
    h, w = min(h1, h2), min(w1, w2)
    return cv2.resize(img1, (w, h)), cv2.resize(img2, (w, h))


def mse(imgA, imgB):
    imgA, imgB = _resize_to_min(imgA, imgB)
    if imgA.ndim == 3:
        imgA = _to_gray(imgA)
        imgB = _to_gray(imgB)
    err = np.mean((imgA.astype("float") - imgB.astype("float")) ** 2)
    return float(err)


def structural_similarity(imgA, imgB):
    if ssim is None:
        raise RuntimeError(
            "skimage is required for SSIM. Install scikit-image."
        )
    imgA, imgB = _resize_to_min(imgA, imgB)
    imgA = _to_gray(imgA)
    imgB = _to_gray(imgB)
    score, _ = ssim(imgA, imgB, full=True)
    return float(score)


def phash_similarity(pathA, pathB):
    if imagehash is None:
        raise RuntimeError(
            "imagehash (and PIL) required for perceptual hash. Install imagehash."
        )
    ha = imagehash.phash(Image.open(pathA))
    hb = imagehash.phash(Image.open(pathB))
    max_bits = ha.hash.size
    hamming = ha - hb
    sim = 1.0 - (hamming / max_bits)
    return float(sim)


def hist_correlation(imgA, imgB, bins=32):
    imgA = cv2.cvtColor(imgA, cv2.COLOR_BGR2HSV)
    imgB = cv2.cvtColor(imgB, cv2.COLOR_BGR2HSV)
    imgA, imgB = _resize_to_min(imgA, imgB)
    histA = cv2.calcHist([imgA], [0, 1], None, [bins, bins], [0, 180, 0, 256])
    histB = cv2.calcHist([imgB], [0, 1], None, [bins, bins], [0, 180, 0, 256])
    cv2.normalize(histA, histA)
    cv2.normalize(histB, histB)
    score = cv2.compareHist(histA, histB, cv2.HISTCMP_CORREL)
    return float(score)


def orb_match_ratio(imgA, imgB, max_features=500):
    imgA_gray = _to_gray(imgA)
    imgB_gray = _to_gray(imgB)
    orb = cv2.ORB_create(nfeatures=max_features)
    kp1, des1 = orb.detectAndCompute(imgA_gray, None)
    kp2, des2 = orb.detectAndCompute(imgB_gray, None)
    if des1 is None or des2 is None:
        return 0.0
    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
    matches = bf.match(des1, des2)
    if not matches:
        return 0.0
    ratio = len(matches) / max(1, min(len(kp1), len(kp2)))
    return float(ratio)


def compare_images(pathA, pathB):
    if not os.path.exists(pathA) or not os.path.exists(pathB):
        raise FileNotFoundError("One or both image paths do not exist.")
    imgA = _read_image_cv(pathA, cv2.IMREAD_COLOR)
    imgB = _read_image_cv(pathB, cv2.IMREAD_COLOR)

    results = {}
    results["mse"] = mse(imgA, imgB)

    if ssim is not None:
        results["ssim"] = structural_similarity(imgA, imgB)
    else:
        results["ssim"] = None
    try:
        results["phash"] = phash_similarity(pathA, pathB)
    except Exception:
        results["phash"] = None
    results["hist_correlation"] = hist_correlation(imgA, imgB)
    results["orb_match_ratio"] = orb_match_ratio(imgA, imgB)

    return results


# -------------------------------
# GET ALL MANGA
# -------------------------------
def get_all_manga(data_dir):
    manga_list = []
    en_dir = Path(data_dir) / "en"

    if not en_dir.exists():
        return manga_list

    for manga in sorted(en_dir.iterdir()):
        if not manga.is_dir():
            continue

        for chapter in sorted(manga.iterdir()):
            if chapter.is_dir():
                manga_list.append((manga.name, chapter.name))

    return manga_list


# -------------------------------
# FILTER MANGA BY RANGE
# -------------------------------
def filter_by_range(item_list, input_range):
    if not input_range:
        return item_list

    if len(input_range) == 1:
        start = input_range[0]
        return item_list[start:]

    start, end = input_range[0], input_range[1]
    return item_list[start:end]


# -------------------------------
# GET SORTED IMAGES
# -------------------------------
def get_sorted_images(folder):
    files = [
        f
        for f in os.listdir(folder)
        if f.lower().endswith((".png", ".jpg", ".jpeg"))
    ]
    files.sort()
    return files


# -------------------------------
# CHECK MATCH
# -------------------------------
def is_match(en_path, vi_path):
    try:
        result = compare_images(en_path, vi_path)

        ssim_score = result.get("ssim", 0)
        hist_correlation_score = result.get("hist_correlation", 0)
        orb_ratio_score = result.get("orb_match_ratio", 0)

        # Pass 1: Strict match
        if ssim_score is not None and hist_correlation_score is not None:
            if (
                ssim_score >= SSIM_THRESHOLD
                and hist_correlation_score >= HIST_CORRELATION_THRESHOLD
            ):
                return True

        # Pass 2: Fallback condition
        if hist_correlation_score is not None and orb_ratio_score is not None:
            if (
                hist_correlation_score >= HIST_CORRELATION_FALLBACK
                and orb_ratio_score >= ORB_MATCH_RATIO_FALLBACK
            ):
                return True

        return False

    except Exception as e:
        print(f"⚠️ Compare error: {e}")
        return False


# -------------------------------
# PROCESS ONE CHAPTER
# -------------------------------
def process_chapter(input_dir, output_dir, manga, chapter, log_file):
    en_path = Path(input_dir) / "en" / manga / chapter
    vi_path = Path(input_dir) / "vi" / manga / chapter

    if not en_path.exists() or not vi_path.exists():
        return

    out_en = Path(output_dir) / "en" / manga / chapter
    out_vi = Path(output_dir) / "vi" / manga / chapter

    out_en.mkdir(parents=True, exist_ok=True)
    out_vi.mkdir(parents=True, exist_ok=True)

    en_images = get_sorted_images(en_path)
    vi_images = get_sorted_images(vi_path)

    vi_idx = 0
    output_idx = 0

    unmatched_en = []
    matched_vi_indices = set()

    for en_img in tqdm(en_images, desc=f"{manga}-{chapter}", leave=False):
        en_full = en_path / en_img
        found = False

        for j in range(vi_idx, len(vi_images)):
            vi_full = vi_path / vi_images[j]

            if is_match(str(en_full), str(vi_full)):
                matched_vi_indices.add(j)
                output_name = f"{output_idx:04d}"
                shutil.copy(en_full, out_en / f"{output_name}{en_full.suffix}")
                shutil.copy(vi_full, out_vi / f"{output_name}{vi_full.suffix}")
                output_idx += 1

                vi_idx = j + 1
                found = True
                break

        if not found:
            unmatched_en.append(en_img)

    unmatched_vi = [
        vi_images[i]
        for i in range(len(vi_images))
        if i not in matched_vi_indices
    ]

    if unmatched_en or unmatched_vi:
        log_file.write(f"{manga} / {chapter}\n")
        log_file.write(f"EN unmatched: {unmatched_en}\n")
        log_file.write(f"VI unmatched: {unmatched_vi}\n\n")


# -------------------------------
# RUN ALIGNMENT
# -------------------------------
print("🔍 Starting EN-VI alignment...")
input_dir = RAW_DIR
output_dir = RAW_UNMATCHED_ONLY_DIR
input_range = []

LOG_FILE = Path(output_dir) / "log.txt"
LOG_FILE.parent.mkdir(parents=True, exist_ok=True)
with open(LOG_FILE, "w", encoding="utf-8") as f:
    f.write("UNMATCHED PAGES LOG\n\n")

manga_list = get_all_manga(input_dir)
manga_list = filter_by_range(manga_list, input_range)

print(f"📋 Processing {len(manga_list)} total items based on range criteria.")

progress_bar = tqdm(manga_list, desc="Processing chapters")
for manga, chapter in progress_bar:
    progress_bar.set_description(f"Processing {manga}/{chapter}")
    try:
        with open(LOG_FILE, "a", encoding="utf-8") as log_f:
            process_chapter(input_dir, output_dir, manga, chapter, log_f)
    except Exception as e:
        tqdm.write(f"❌ Error: {manga}/{chapter} | {e}")

print("\n🎉 DONE!")
# Out:
# 🔍 Starting EN-VI alignment...
# 📋 Processing 2282 total items based on range criteria.
# Processing Alma/Vol. 1 Ch. 2:   0%|          | 1/2282 [00:41<26:13:41, 41.39s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 299
#     297 try:
#     298     with open(LOG_FILE, "a", encoding="utf-8") as log_f:
# --> 299         process_chapter(input_dir, output_dir, manga, chapter, log_f)
#     300 except Exception as e:
#     301     tqdm.write(f"❌ Error: {manga}/{chapter} | {e}")
#
# Cell In[20], line 250, in process_chapter(input_dir, output_dir, manga, chapter, log_file)
#     247 for j in range(vi_idx, len(vi_images)):
#     248     vi_full = vi_path / vi_images[j]
# --> 250     if is_match(str(en_full), str(vi_full)):
#     251         matched_vi_indices.add(j)
#     252         output_name = f"{output_idx:04d}"
#
# ...

# %% [markdown]
# # Move manga with un-equal number of page per chapter (run filter_matched_only.py first)

# %%
import os
import shutil
from datetime import datetime

unequal_page_dir = os.path.join(os.path.dirname(data_dir), "missing_pages")
languages = ["en", "vi"]
manga_common = set(os.listdir(os.path.join(data_dir, "en"))) & set(
    os.listdir(os.path.join(data_dir, "vi"))
)
unequal_page_dir_log_path = os.path.join(unequal_page_dir, "history_log.txt")

for lang in languages:
    os.makedirs(os.path.join(unequal_page_dir, lang), exist_ok=True)


def list_dirs(path):
    return [
        name for name in os.listdir(path) if os.path.isdir(os.path.join(path, name))
    ]


for manga in manga_common:
    # Get chapter lists for both languages
    en_chapters = list_dirs(os.path.join(data_dir, "en", manga))
    vi_chapters = list_dirs(os.path.join(data_dir, "vi", manga))
    # Only check chapters that exist in both
    common_chapters = set(en_chapters) & set(vi_chapters)
    unequal = False
    for chapter in common_chapters:
        en_pages = os.listdir(os.path.join(data_dir, "en", manga, chapter))
        vi_pages = os.listdir(os.path.join(data_dir, "vi", manga, chapter))
        if len(en_pages) != len(vi_pages):
            unequal = True
            break
    if unequal:
        for lang in languages:
            src = os.path.join(data_dir, lang, manga)
            dst = os.path.join(unequal_page_dir, lang, manga)
            if os.path.exists(src):
                shutil.move(src, dst)
                log_entry = f"{datetime.now().isoformat()} - {manga} → {lang}\n"
                print(log_entry)
                with open(unequal_page_dir_log_path, "a") as log_file:
                    log_file.write(log_entry)
# Out:
# 2025-11-05T18:20:49.435912 - Koi yori Aoku → en
#
# 2025-11-05T18:20:49.436905 - Koi yori Aoku → vi
#
# 2025-11-05T18:20:49.438058 - Soshiki no Shukuteki to Kekkon Shitara Mecha Amai → en
#
# 2025-11-05T18:20:49.438941 - Soshiki no Shukuteki to Kekkon Shitara Mecha Amai → vi
#
# 2025-11-05T18:20:49.440309 - Imokusa Reijou desu ga Akuyaku Reisoku wo Tasuketara Kiniiraremashita → en
#
# 2025-11-05T18:20:49.441014 - Imokusa Reijou desu ga Akuyaku Reisoku wo Tasuketara Kiniiraremashita → vi
#
# 2025-11-05T18:20:49.441817 - FateSamurai Remnant → en
#
# 2025-11-05T18:20:49.442288 - FateSamurai Remnant → vi
#
# 2025-11-05T18:20:49.443110 - Nibanme na Boku to Ichiban no Kanojo → en
#
# 2025-11-05T18:20:49.443534 - Nibanme na Boku to Ichiban no Kanojo → vi
#
# 2025-11-05T18:20:49.444434 - Okinawa de Suki ni Natta Ko ga Hougen Sugite Tsura Sugiru → en
#
# 2025-11-05T18:20:49.444869 - Okinawa de Suki ni Natta Ko ga Hougen Sugite Tsura Sugiru → vi
#
# 2025-11-05T18:20:49.448618 - Shy → en
#
# ...

# %% [markdown]
# # Move remaining valid data to raw_processed

# %%
import os
import shutil

raw_dir = data_dir
raw_processed_dir = os.path.join(os.path.dirname(data_dir), "raw_processed")
os.makedirs(raw_processed_dir, exist_ok=True)
# Move all the remaining valid manga folder from the original dir to a new valid one

for folder in os.listdir(raw_dir):
    folder_path = os.path.join(raw_dir, folder)
    dest_path = os.path.join(raw_processed_dir, folder)
    os.makedirs(dest_path, exist_ok=True)

    for manga_title in os.listdir(folder_path):
        manga_title_path = os.path.join(folder_path, manga_title)
        shutil.move(manga_title_path, dest_path)
        print(f"Move {manga_title} from {folder_path}")
# Out:
# Move Almark from ../data/raw\en
# Move Fami-res Iko from ../data/raw\en
# Move Itsuka Fukushuu Suru Sono Tame ni from ../data/raw\en
# Move Toukyou KINOKO Sekai Ranking 1-i no Komyu-ryoku Saijaku JK from ../data/raw\en
# Move Yuusha Party kara Oidasareta Fuguushoku [Wanashi] Yunikku Sukiru [Yajirushi] de Saikyou ni Naru from ../data/raw\en
# Move Almark from ../data/raw\vi
# Move Fami-res Iko from ../data/raw\vi
# Move Itsuka Fukushuu Suru Sono Tame ni from ../data/raw\vi
# Move Toukyou KINOKO Sekai Ranking 1-i no Komyu-ryoku Saijaku JK from ../data/raw\vi
# Move Yuusha Party kara Oidasareta Fuguushoku [Wanashi] Yunikku Sukiru [Yajirushi] de Saikyou ni Naru from ../data/raw\vi
